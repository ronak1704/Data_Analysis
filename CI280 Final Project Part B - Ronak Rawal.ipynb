# %% [markdown]
# # CI280 - Final Project - Part B
# #
# # Data Preparation, Sort, Groupby and Plot( 100 pts)
#
# ## Name

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 8))

# %%
df = pd.read_csv('covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# ...        ...            ...            ...         ...          ...
# 56319      NaN            NaN  International  2020-11-11        696.0
# 56320      NaN            NaN  International  2020-11-12        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           NaN         0.0
# 1            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 56319        NaN                 NaN           7.0         NaN
# 56320        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# ...

# %%
df = df[ (df['location'] != 'World') ]
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# ...        ...            ...            ...         ...          ...
# 56319      NaN            NaN  International  2020-11-11        696.0
# 56320      NaN            NaN  International  2020-11-12        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           NaN         0.0
# 1            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 56319        NaN                 NaN           7.0         NaN
# 56320        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                      NaN  ...       35973.781              NaN
# ...

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("Ronak Rawal,20209 ", number )
print('------------------------------')
# Out:
# Ronak Rawal,20209  9090
# ------------------------------

# %% [markdown]
# ## C) Handing Missing Data and Ploting (20 pts)
#
# ### use isnull() vs. notnull()
# ### use dropna
# ### use replacena

# %%
# show last five rows
df.tail()
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# 56320                 NaN           7.0         NaN                  NaN  ...
#
# ...

# %%
# show the number of rows and columns of datafram 
df.shape
number = random.randint(0,10000)
print("Ronak Rawal , 20209 ", number )
print('------------------------------')

# 1) Show the number records of miss data for continent ( 2 pts)
#    Show the the last five those records 

print('The number records missing data for continent')
print(df['continent'].isna().sum())
df[df['continent'].isna() == True].tail()
# Out:
# Ronak Rawal , 20209  2185
# ------------------------------
# The number records missing data for continent
# 636
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# 56319                 NaN           7.0         NaN                  NaN  ...
# ...

# %%
number = random.randint(0,10000)
print("Ronak Rawal , 20209", number )
print('------------------------------')


# 2-3) Show the number records of miss data for continent and iso_code (2 pts)
#    Show the the last five those records ( 2 pts)

print('The number records missing data for continent and iso_code')
print(len(df[df['continent'].isnull() & df['iso_code'].isnull()]))
df[df['continent'].isnull() & df['iso_code'].isnull()].tail()
# Out:
# Ronak Rawal , 20209 3600
# ------------------------------
# The number records missing data for continent and iso_code
# 318
#       iso_code continent       location        date  total_cases  new_cases  \
# 56316      NaN       NaN  International  2020-11-08        696.0        NaN
# 56317      NaN       NaN  International  2020-11-09        696.0        NaN
# 56318      NaN       NaN  International  2020-11-10        696.0        NaN
# 56319      NaN       NaN  International  2020-11-11        696.0        NaN
# 56320      NaN       NaN  International  2020-11-12        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 56316                 NaN           7.0         NaN                  NaN  ...
# 56317                 NaN           7.0         NaN                  NaN  ...
# 56318                 NaN           7.0         NaN                  NaN  ...
# ...

# %%
number = random.randint(0,10000)
print("Ronak Rawal , 20209", number )
print('------------------------------')



# 4-5) For the records for Bazil, which columns has missing data (4 pts)
res = df[df['location']=='Russia']
res
#print(res.head())
col_names = res.columns
col_names

print('The following columns ar missing data for Russia')

res[res.isnull().any(axis=1)].count()
# Out:
# Ronak Rawal , 20209 5454
# ------------------------------
# The following columns ar missing data for Russia
# iso_code                              318
# continent                             318
# location                              318
# date                                  318
# total_cases                           286
# new_cases                             318
# new_cases_smoothed                    312
# total_deaths                          231
# new_deaths                            318
# new_deaths_smoothed                   312
# total_cases_per_million               286
# new_cases_per_million                 318
# new_cases_smoothed_per_million        312
# total_deaths_per_million              231
# new_deaths_per_million                318
# new_deaths_smoothed_per_million       312
# icu_patients                            0
# icu_patients_per_million                0
# hosp_patients                           0
# hosp_patients_per_million               0
# ...

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209", number )
print('------------------------------')


#df.columns

df.shape
# .dropna() vs. . dropna(how='all')

# 6) Show the result after droping rows which have at least one NaN data in the dataset ()  (2 pts)
print("After using .dropn(), total records: ")
df.dropna(thresh=len(df)-1,inplace=True)
print(len(df))
# Out:
# Ronak Rawal ,20209 4456
# ------------------------------
# After using .dropn(), total records:
# 0

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

# 7) Show the result after after droping rows which all data is NaN in the dataset ()  (2 pts)

print('After using dropna(how=all), total records:')
df.dropna(thresh = 0,inplace=True)
df.shape[0]
# Out:
# Ronak Rawal ,20209  4605
# ------------------------------
# After using dropna(how=all), total records:
# 0

# %%
number = random.randint(0,10000)
print("Ronak Rawal , 20209 ", number )
print('------------------------------')

print(df.shape)
print('Original row number:', len(df))

# 8) Show the result after dropping the rows which continent or iso data is missing in the dataset
#    How many rows are dropped. (2 pts)

data = df[['continent','iso_code']]
data.dropna(inplace = True)

print('After droping all missing data of continent or iso in the dataset\nNew dataset included record number:',len(data))
print('The number of rows dropped:', len(df) - len(data))
# Out:
# Ronak Rawal , 20209  1193
# ------------------------------
# (0, 49)
# Original row number: 0
# After droping all missing data of continent or iso in the dataset
# New dataset included record number: 0
# The number of rows dropped: 0
# <ipython-input-21-569b9fbdd5d8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace = True)

# %%
res = df[df['location']=='Russia']
res[['location','handwashing_facilities']]
# Out:
#       location  handwashing_facilities
# 43445   Russia                     NaN
# 43446   Russia                     NaN
# ...        ...                     ...
# 43761   Russia                     NaN
# 43762   Russia                     NaN
#
# [318 rows x 2 columns]

# %%
# 9) Show Brazil's handwashing_facilities information
#    Show the average of handwashing_facilities of worldwide level

import random
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

#print(df['handwashing_facilities'].describe())


print("Handwashing_facilities values are missing in Russia")
res = df[[df['location']=='Russia']['handwashing_facilities' == 'NaN']]
print(len(res))
print(res[['location','date','handwashing_facilities']])


print('---------------------------------------------------------------------')
print('The average of handwashing_facilities of worldwide is:',df['handwashing_facilities'].mean())
# Out:
# Ronak Rawal ,20209  5617
# ------------------------------
# Handwashing_facilities values are missing in Russia
# 0
# Empty DataFrame
# Columns: [location, date, handwashing_facilities]
# Index: []
# ---------------------------------------------------------------------
# The average of handwashing_facilities of worldwide is: nan

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

import math

# 10) Replace handwashing_facilities in Brazil as the average of worldwide level (2 pts)


res = df[df['location']== 'Russia']
res['handwashing_facilities'].fillna(df['handwashing_facilities'].mean(),inplace = True)

print("Now handwashing_facilities values are replace by the average of worldwide level")

print(res[['location','date','handwashing_facilities']])
# Out:
# Ronak Rawal ,20209  4691
# ------------------------------
# Now handwashing_facilities values are replace by the average of worldwide level
# Empty DataFrame
# Columns: [location, date, handwashing_facilities]
# Index: []

# %% [markdown]
# # D) Sorting, Grouping and Plotting (30 points)
#
# ## df.sort_values(by=['a','b'], ascending = True)
# ## df.sort_index()
# ## df.groupby( )

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')
import matplotlib.pyplot as plt

# 1)  (3 pts) Find the top 10 countries which have the most covid cases

# Group all cases by location , become series
cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)

print('10 countries which have the most covid cases')
print('------------------------------------------------')
cases = cases.head(10)
cases = pd.DataFrame({'Country':cases.index, 'Covid Cases':cases.values })
cases
# Out:
# Ronak Rawal ,20209  5379
# ------------------------------
# 10 countries which have the most covid cases
# ------------------------------------------------
#           Country  Covid Cases
# 0   United States   10401132.0
# 1           India    8683916.0
# ..            ...          ...
# 8        Colombia    1165326.0
# 9           Italy    1028424.0
#
# [10 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')


# 2) Use bar chart to show the top 10 countries which have the most covid cases. (3 pts)


cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases = cases.head(10)

ax = cases.plot.bar(x='location', y='cases',figsize = (7,5), title = '10 countires which have the most covid cases')
# Out:
# Ronak Rawal ,20209  294
# ------------------------------

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

# (3  pts)

# 3) Show worldwide, which ten day has the most new cases? 
cases = df.groupby(df.date).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases = cases.head(10)
print(cases)
#    Use line chart to show the top 10 days which have the most new covid cases 
cases = cases.sort_index()


ax = cases.plot.line(x='date', y='cases',figsize = (11,10), title = '10 countires which have the most covid cases') 

    
    
# Draw bar chart
# Out:
# Ronak Rawal ,20209  968
# ------------------------------
# date
# 2020-11-06    590129.0
# 2020-11-07    584512.0
#                 ...
# 2020-10-31    542125.0
# 2020-11-09    518189.0
# Name: new_cases, Length: 10, dtype: float64

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

# (3  pts)

# 4) On 2020-11-30, which ten countries has the most new cases? 

#    Use bar chart to show the top 10 location which have the most new covid cases 


df[df['date'] == '2020-11-30']


# Draw bar chart
# Out:
# Ronak Rawal ,20209  605
# ------------------------------
# Empty DataFrame
# ...

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')

# (3  pts)


#  5)  Show last seven days, the new cases in Brazil/US/India/Russia (Chose one country),
#      Plot a line chart


dt = df[df['location'] == 'Russia']
new_dt = dt.tail(7)
new_d = pd.DataFrame({'Date':new_dt.date, 'Covid Cases':new_dt.new_cases })
print(new_d)

new_d.plot('Date', 'Covid Cases',kind='line')
plt.xlabel('date')
plt.ylabel(' Numbers')
plt.title('New covid cases in past 7 days')
#plt.grid()
plt.show()
# Out:
# Ronak Rawal ,20209  3703
# ------------------------------
#              Date  Covid Cases
# 43756  2020-11-06      19404.0
# 43757  2020-11-07      20582.0
# ...           ...          ...
# 43761  2020-11-11      20977.0
# 43762  2020-11-12      19851.0
#
# [7 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("Ronak Rawal ,20209 ", number )
print('------------------------------')


# 6-7) Group by contient, show total of new covid cases for each contient and sorted by total number
#    Plot the result by pie chart (3 pts)


new = df[['continent','new_cases']]
new.dropna(inplace = True)
newer = new.groupby(by=["continent"]).sum()
print(newer)




fig1, ax1 = plt.subplots()
ax1.pie(newer['new_cases'], labels= newer.index, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Ronak Rawal ,20209  8009
# ------------------------------
#                 new_cases
# continent
# Africa          1918097.0
# Asia           14762053.0
# ...                   ...
# Oceania           46830.0
# South America  10064053.0
#
# [6 rows x 1 columns]
# <ipython-input-34-3ddd9305b7ee>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.dropna(inplace = True)

# %%
res
# Out:
#             location    population
# 10332          China  1.439324e+09
# 24490          India  1.380004e+09
# ...              ...           ...
# 56476        Vatican  8.090000e+02
# 59920  International           NaN
#
# [190 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("Ronak Rawal,20209 ", number )
print('------------------------------')
import numpy as np

# 8) Show the top 10 countries which have the most population  (3 pts)



print('Top 10 counties which have the most POPULATION')
 

new_data = df[['location','population']]
new_data = new_data[new_data['location'] != 'World']
new_data.dropna(inplace = True)


newer = new_data.groupby(by=["location"]).sum()
data = newer.sort_values(by =['population'], ascending = False)
data = data.head(10)
data = data['population']
data['location'] = data.index
print(data)
# Out:
# Ronak Rawal,20209  829
# ------------------------------
# Top 10 counties which have the most POPULATION
# location
# China                                             4.57705e+11
# India                                             4.38841e+11
#                                   ...
# Mexico                                            4.10006e+10
# location    Index(['China', 'India', 'United States', 'Ind...
# Name: population, Length: 11, dtype: object

# %%
number = random.randint(0,10000)
print("Ronak Rawal , 20209 ", number )
print('------------------------------')

# 9-10) Show the world poplation
#      Show the  population by each continent and show it as pie chart (6 pts)
world_data = df[df['location'] == 'World']
world_data = world_data[['location','population']]
total_population = world_data['population'].sum()



new = df[['continent','population']]
new.dropna(inplace = True)
newer = new.groupby(by=["continent"]).sum()


print('-------------------------------------')
print('the world population',newer['population'].sum(), 'population by Continent')

print(newer)


fig1, ax1 = plt.subplots()
ax1.pie(newer['population'], labels= newer.index, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Ronak Rawal , 20209  9850
# ------------------------------
# -------------------------------------
# the world population 2328774345321.0 population by Continent
#                  population
# continent
# Africa         3.541667e+11
# Asia           1.427892e+12
# ...                     ...
# Oceania        1.223029e+10
# South America  1.235340e+11
#
# [6 rows x 1 columns]
# <ipython-input-36-ef4867109e6a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new.dropna(inplace = True)
